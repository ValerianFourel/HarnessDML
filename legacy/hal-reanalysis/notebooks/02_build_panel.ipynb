# %% [markdown]
# # 02 — Build analysis panel (Phase 2)
#
# **OFFLINE-SAFE — runs on compute nodes.** One row per rollout →
# `results/panel/<benchmark>.parquet`, plus reconciliation (counts vs. paper's
# 21,730), missingness and duplicate reports into `results/diagnostics/`.
#
# Blocked until `schema/SCHEMA.md` exists and is reviewed (CLAUDE.md, Phase 1).

# %%
from halcausal.etl import build_panel

# build_panel(benchmark="taubench_airline")   # NotImplemented until Phase 2
build_panel
