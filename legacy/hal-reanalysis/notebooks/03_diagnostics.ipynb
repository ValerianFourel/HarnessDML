# %% [markdown]
# # 03 — Design diagnostics (Phase 3, BEFORE any estimation)
#
# **OFFLINE-SAFE.** Support cross-tabs (model × scaffold × benchmark ×
# reasoning), overlap heatmap, machine-readable estimable-contrast list,
# propensity distributions with [0.02, 0.98] trimming, leakage-safe
# task-difficulty covariate — and `results/diagnostics/design_notes.md`,
# without which notebook 04 refuses to run.

# %%
from halcausal.diagnostics import run_diagnostics

# run_diagnostics(panel="results/panel/taubench_airline.parquet")   # NotImplemented until Phase 3
run_diagnostics
