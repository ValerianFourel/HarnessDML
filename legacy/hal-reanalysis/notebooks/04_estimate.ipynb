# %% [markdown]
# # 04 — DML estimation (Phase 4)
#
# **OFFLINE-SAFE.** Config-driven, one estimand per `configs/*.yaml`:
# DoubleMLIRM/PLR, LightGBM nuisances, 5-fold cross-fitting, `n_rep=3`,
# cluster-robust at `task_id`, comparison ladder (naive / clustered-OLS / DML),
# GATEs, multiplier-bootstrap simultaneous CIs, sensitivity analysis.

# %%
from halcausal import guards

guards.require_design_notes()   # Phase-3 gate: hard-errors if design_notes.md is absent

# %%
from halcausal.estimation import estimate

# estimate("configs/estimand_reasoning_taubench.yaml")   # NotImplemented until Phase 4
estimate
